# %% [markdown]
# # Attrape moi si tu peux
#
# ## Sommaire :
#
# -   [Import du Dataset](#Import-du-dataset)
# -   [Fonctions utiles](#Initialisation-des-fonctions-utiles-pour-le-test)
# -   [Couche Conv2D](#Conv2D)
# -   [Pooling (Max et Average)](#Pooling-(Max-et-Average))
# -   [Dropout](#Droupout)
# -   [Dense](#Dense)

# %%
### IMPORTS ###

import matplotlib.pyplot as plt
import cv2
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import random
import tensorflow as tf
import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, Activation, Dropout, Flatten, Dense, Dropout
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

### Définition de la seed de tensorflow ###

tf.random.set_seed(2)

# %%
### Inspection de la shape d'une image ###

new_image = cv2.imread("data/RAW/train/bear/0001.png")
print(new_image.shape)
# Out:
# (32, 32, 3)

# %% [markdown]
# # Import du dataset
#
# On utilise le module ImageDataGenerator pour récupérer les images présentes dans les différents dossier et les transformer en array.

# %%
### Déclaration des constantes ###

TRAIN_BASE_DIRECTORY = "./data/test/train"
TEST_BASE_DIRECTORY = "./data/test/test"
TRAIN_IMAGE_SIZE = 32
TRAIN_BATCH_SIZE = 64

# %%
image_data_generator = ImageDataGenerator(validation_split=0.5)

train_generator = image_data_generator.flow_from_directory(
    TRAIN_BASE_DIRECTORY,
    target_size=(TRAIN_IMAGE_SIZE, TRAIN_IMAGE_SIZE),
    batch_size=TRAIN_BATCH_SIZE,
    class_mode='categorical',
    subset='training',
    seed=5)

validation_generator = image_data_generator.flow_from_directory(
    TEST_BASE_DIRECTORY,
    target_size=(TRAIN_IMAGE_SIZE, TRAIN_IMAGE_SIZE),
    batch_size=TRAIN_BATCH_SIZE,
    class_mode='categorical',
    subset='training',
    seed=5)
# Out:
# Found 500 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.

# %% [markdown]
# # Initialisation des fonctions utiles pour le test

# %%
### Affichage des graphiques présentant les valeurs de loss et d'accuracy ###

def print_model_history(history):
    '''
        print model training history
    '''
    # list all data in history
    print(history.history.keys())
    plt.figure(figsize=(20,5))

    plt.subplot(1,2,1)
    # summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')

    plt.subplot(1,2,2)
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# print_model_history(training)

# %%
### Inspection d'une couche dans le modèle ###

def display_activation(model, col_size, row_size, act_index):

    layer_outputs = [layer.output for layer in model.layers]
    test_image = "./data/test/test/bus/0020.png"

    # Le chargement de l'image doit être augmenté puisque notre modèle prend des lots d'images.
    img = image.load_img(test_image, target_size=(32,32, 3))
    img_arr = image.img_to_array(img)
    img_arr = np.expand_dims(img_arr, axis=0)

    activation_model = Model(inputs=model.input, outputs=layer_outputs)
    activations = activation_model.predict(img_arr)

 
    activation = activations[act_index]
    activation_index=0
    fig, ax = plt.subplots(row_size, col_size, figsize=(row_size*13.5,col_size*2.5))
    for row in range(0,row_size):
        for col in range(0,col_size):
            ax[row][col].imshow(activation[0, :, :, activation_index])
            activation_index += 1

# display_activation(model, 8, 4, 4)

# %%
### Prédiction de l'objet présent sur une image ###

def predict(model):
    labels_array = os.listdir(TRAIN_BASE_DIRECTORY)

    choix = r"./data/lion.png"

    test_image = image.load_img(choix, target_size = (32, 32))
    plt.imshow(test_image)
    test_image = image.img_to_array(test_image)

    test_image = np.expand_dims(test_image, axis = 0)
    result = model.predict(test_image)

    preds = model.predict_classes(test_image)
    prob = model.predict_proba(test_image)

    index = preds[0]
    print(f'Cet objet est un(e) {labels_array[index]}.', 'probs= ', prob[0][index] * 100)

# predict(model)

# %% [markdown]
# # Test des différentes couches sur différents modèles
#
# Dans cette partie nous allons tester les différentes couches proposées par Keras et voir leur impact sur les images. Les images utilisées seront toujours les mêmes.

# %% [markdown]
# # Conv2D
#
# Cette couche sert à créer une feature map, elle "trouve" les paramètres sur l'image.

# %%
model = Sequential()

model.add(Conv2D(32, kernel_size=3, activation='relu', padding='same', input_shape=(32,32,3))) ### La taille du kernel définit la précision de la convolution et influe sur la taille de l'image en sortie

### Fin obligatoire ###
model.add(Flatten())
model.add(Dense(2, activation='softmax')) ### Le paramètre dans cette fonction Dense doit être égal au nombre de catégories recherchées

model.summary()

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

training = model.fit_generator(train_generator, epochs=10, validation_data=validation_generator, shuffle=False)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 65538
# =================================================================
# Total params: 66,434
# Trainable params: 66,434
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From <ipython-input-8-d76a37ec6596>:13: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/10
# 8/8 [==============================] - 1s 66ms/step - loss: 359.5824 - accuracy: 0.5200 - val_loss: 21.1473 - val_accuracy: 0.8000
# Epoch 2/10
# 8/8 [==============================] - 0s 49ms/step - loss: 59.0684 - accuracy: 0.7080 - val_loss: 85.8436 - val_accuracy: 0.7000
# Epoch 3/10
# 8/8 [==============================] - 0s 52ms/step - loss: 48.5138 - accuracy: 0.7900 - val_loss: 31.2389 - val_accuracy: 0.8300
# Epoch 4/10
# 8/8 [==============================] - 1s 81ms/step - loss: 21.2171 - accuracy: 0.8700 - val_loss: 8.5631 - val_accuracy: 0.9200
# Epoch 5/10
# 8/8 [==============================] - 0s 49ms/step - loss: 13.4311 - accuracy: 0.8840 - val_loss: 7.6633 - val_accuracy: 0.9000
# Epoch 6/10
# 8/8 [==============================] - 0s 49ms/step - loss: 6.7932 - accuracy: 0.9180 - val_loss: 3.0536 - val_accuracy: 0.9600
# Epoch 7/10
# 8/8 [==============================] - 0s 50ms/step - loss: 2.4651 - accuracy: 0.9420 - val_loss: 2.4820 - val_accuracy: 0.9600
# Epoch 8/10
# 8/8 [==============================] - 0s 49ms/step - loss: 1.5682 - accuracy: 0.9620 - val_loss: 2.2640 - val_accuracy: 0.9700
# Epoch 9/10
# 8/8 [==============================] - 0s 49ms/step - loss: 0.9303 - accuracy: 0.9800 - val_loss: 2.0379 - val_accuracy: 0.9700
# Epoch 10/10
# 8/8 [==============================] - 0s 49ms/step - loss: 0.3982 - accuracy: 0.9860 - val_loss: 2.3106 - val_accuracy: 0.9600

# %%
display_activation(model, 8, 4, 0)
print("Conv2D avec un kernel à 3")
# Out:
# Conv2D avec un kernel à 3

# %%
model = Sequential()

model.add(Conv2D(32, kernel_size=5, activation='relu', padding='same', input_shape=(32,32,3))) ### La taille du kernel définit la précision de la convolution et influe sur la taille de l'image en sortie

### Fin obligatoire ###
model.add(Flatten())
model.add(Dense(2, activation='softmax')) ### Le paramètre dans cette fonction Dense doit être égal au nombre de catégories recherchées

model.summary()

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

training = model.fit_generator(train_generator, epochs=10, validation_data=validation_generator, shuffle=False)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        2432
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 65538
# =================================================================
# Total params: 67,970
# Trainable params: 67,970
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 8/8 [==============================] - 1s 76ms/step - loss: 248.3324 - accuracy: 0.5140 - val_loss: 30.6765 - val_accuracy: 0.6900
# Epoch 2/10
# 8/8 [==============================] - 1s 63ms/step - loss: 23.1385 - accuracy: 0.6960 - val_loss: 10.7035 - val_accuracy: 0.7400
# Epoch 3/10
# 8/8 [==============================] - 0s 58ms/step - loss: 5.1802 - accuracy: 0.7980 - val_loss: 2.7440 - val_accuracy: 0.8100
# Epoch 4/10
# 8/8 [==============================] - 0s 57ms/step - loss: 1.4162 - accuracy: 0.8660 - val_loss: 1.6120 - val_accuracy: 0.7700
# Epoch 5/10
# 8/8 [==============================] - 0s 60ms/step - loss: 0.7874 - accuracy: 0.8540 - val_loss: 1.3064 - val_accuracy: 0.7900
# Epoch 6/10
# 8/8 [==============================] - 0s 54ms/step - loss: 0.5396 - accuracy: 0.8680 - val_loss: 1.0019 - val_accuracy: 0.8200
# Epoch 7/10
# 8/8 [==============================] - 0s 54ms/step - loss: 0.3884 - accuracy: 0.8940 - val_loss: 0.7739 - val_accuracy: 0.8100
# Epoch 8/10
# 8/8 [==============================] - 0s 53ms/step - loss: 0.3017 - accuracy: 0.9040 - val_loss: 0.6857 - val_accuracy: 0.8300
# Epoch 9/10
# 8/8 [==============================] - 0s 53ms/step - loss: 0.2247 - accuracy: 0.9140 - val_loss: 0.6453 - val_accuracy: 0.8400
# Epoch 10/10
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1701 - accuracy: 0.9440 - val_loss: 0.6594 - val_accuracy: 0.8500

# %%
display_activation(model, 8, 4, 0)
print("Conv2D avec un kernel à 5")
# Out:
# Conv2D avec un kernel à 5

# %% [markdown]
# ## Conclusion
#
# Sur notre image de dimensions 32x32, une convolution avec un kernel à 5 est trop aggressive. Nous retiendront donc une convolution avec un kernal à 3 pour la suite.

# %% [markdown]
# # Pooling (Max et Average)
#
# Le pooling sert à "exagérer" l'image, pour se faire nous allons parcourir l'image avec un rectangle dont nous allons choisir la taille. Plus ce rectangle sera grand, plus la taille de l'image sera réduite.
#
# __ATTENTION__ : ce dernier ne génère aucun paramètre et est donc inutile sans convolution. Dans les exemples suivants, nous allons simplement étudier son effet sur l'image.
#
# __ATTENTION 2__ : Il est possible de déformer l'image avec le pooling si les proportions du carré parcourant l'image ne sont pas les mêmes que celles de l'image. Nos images étant des carrés de 32x32, nous devons garder un carré pour parcourir l'image.

# %%
model = Sequential()

model.add(Dense(32, activation='relu', input_shape=(32,32,3)))
model.add(MaxPooling2D(pool_size=(2, 2))) ### Le MaxPooling ressort la valeur la plus haute présente dans le rectangle parcourant l'image

### Fin obligatoire ###
model.add(Flatten())
model.add(Dense(2, activation='softmax')) ### Le paramètre dans cette fonction Dense doit être égal au nombre de catégories recherchées

model.summary()

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

training = model.fit_generator(train_generator, epochs=10, validation_data=validation_generator, shuffle=False)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 2)                 16386
# =================================================================
# Total params: 16,514
# Trainable params: 16,514
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 8/8 [==============================] - 1s 70ms/step - loss: 21.7355 - accuracy: 0.6540 - val_loss: 14.9498 - val_accuracy: 0.7300
# Epoch 2/10
# 8/8 [==============================] - 0s 51ms/step - loss: 10.9628 - accuracy: 0.8380 - val_loss: 6.1448 - val_accuracy: 0.8800
# Epoch 3/10
# 8/8 [==============================] - 0s 49ms/step - loss: 6.5238 - accuracy: 0.8580 - val_loss: 2.7378 - val_accuracy: 0.9100
# Epoch 4/10
# 8/8 [==============================] - 0s 51ms/step - loss: 3.2915 - accuracy: 0.8980 - val_loss: 1.9254 - val_accuracy: 0.9200
# Epoch 5/10
# 8/8 [==============================] - 0s 50ms/step - loss: 2.2270 - accuracy: 0.8880 - val_loss: 3.5045 - val_accuracy: 0.8600
# Epoch 6/10
# 8/8 [==============================] - 0s 48ms/step - loss: 1.6735 - accuracy: 0.9040 - val_loss: 3.9678 - val_accuracy: 0.8500
# Epoch 7/10
# 8/8 [==============================] - 0s 53ms/step - loss: 1.1014 - accuracy: 0.9300 - val_loss: 1.3676 - val_accuracy: 0.9400
# Epoch 8/10
# 8/8 [==============================] - 0s 49ms/step - loss: 0.8943 - accuracy: 0.9380 - val_loss: 1.3400 - val_accuracy: 0.9400
# Epoch 9/10
# 8/8 [==============================] - 0s 49ms/step - loss: 0.9023 - accuracy: 0.9440 - val_loss: 1.7508 - val_accuracy: 0.9200
# Epoch 10/10
# 8/8 [==============================] - 0s 50ms/step - loss: 0.8602 - accuracy: 0.9520 - val_loss: 2.6543 - val_accuracy: 0.9000

# %%
display_activation(model, 8, 4, 1)
print("MaxPooling")
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000027F89FF2F70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# MaxPooling

# %%
model = Sequential()

model.add(Dense(32, activation='relu', input_shape=(32,32,3)))
model.add(AveragePooling2D(pool_size=(2, 2))) ### Le MaxPooling ressort la valeur moyenne des pixels présents dans le rectangle parcourant l'image

### Fin obligatoire ###
model.add(Flatten())
model.add(Dense(2, activation='softmax')) ### Le paramètre dans cette fonction Dense doit être égal au nombre de catégories recherchées

model.summary()

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

training = model.fit_generator(train_generator, epochs=10, validation_data=validation_generator, shuffle=False)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 32, 32, 32)        128
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 16, 16, 32)        0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 2)                 16386
# =================================================================
# Total params: 16,514
# Trainable params: 16,514
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 8/8 [==============================] - 1s 67ms/step - loss: 43.9891 - accuracy: 0.5080 - val_loss: 11.1721 - val_accuracy: 0.7200
# Epoch 2/10
# 8/8 [==============================] - 0s 49ms/step - loss: 16.0899 - accuracy: 0.6740 - val_loss: 16.4267 - val_accuracy: 0.7000
# Epoch 3/10
# 8/8 [==============================] - 0s 49ms/step - loss: 11.8460 - accuracy: 0.7760 - val_loss: 10.1339 - val_accuracy: 0.7700
# Epoch 4/10
# 8/8 [==============================] - 0s 58ms/step - loss: 6.4985 - accuracy: 0.8580 - val_loss: 3.6047 - val_accuracy: 0.9000
# Epoch 5/10
# 8/8 [==============================] - 1s 88ms/step - loss: 4.6278 - accuracy: 0.8920 - val_loss: 4.2696 - val_accuracy: 0.9000
# Epoch 6/10
# 8/8 [==============================] - 0s 51ms/step - loss: 3.7522 - accuracy: 0.8940 - val_loss: 2.0946 - val_accuracy: 0.9200
# Epoch 7/10
# 8/8 [==============================] - 0s 52ms/step - loss: 2.6897 - accuracy: 0.9060 - val_loss: 2.1479 - val_accuracy: 0.9300
# Epoch 8/10
# 8/8 [==============================] - 0s 50ms/step - loss: 2.1446 - accuracy: 0.9100 - val_loss: 1.3300 - val_accuracy: 0.9400
# Epoch 9/10
# 8/8 [==============================] - 0s 53ms/step - loss: 1.4615 - accuracy: 0.9260 - val_loss: 1.1059 - val_accuracy: 0.9400
# Epoch 10/10
# 8/8 [==============================] - 0s 48ms/step - loss: 1.0704 - accuracy: 0.9300 - val_loss: 1.1560 - val_accuracy: 0.9300

# %%
display_activation(model, 8, 4, 1)
print("AveragePooling")
# Out:
# WARNING:tensorflow:7 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000027F87F218B0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# AveragePooling

# %%
model = Sequential()

model.add(Dense(32, activation='relu', input_shape=(32,32,3)))
model.add(MaxPooling2D(pool_size=(3, 2))) ### Le MaxPooling ressort la valeur la plus haute présente dans le rectangle parcourant l'image

### Fin obligatoire ###
model.add(Flatten())
model.add(Dense(2, activation='softmax')) ### Le paramètre dans cette fonction Dense doit être égal au nombre de catégories recherchées

model.summary()

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

training = model.fit_generator(train_generator, epochs=10, validation_data=validation_generator, shuffle=False)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_13 (Dense)             (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 16, 32)        0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 5120)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 2)                 10242
# =================================================================
# Total params: 10,370
# Trainable params: 10,370
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 8/8 [==============================] - 1s 70ms/step - loss: 72.5951 - accuracy: 0.5000 - val_loss: 21.4700 - val_accuracy: 0.5400
# Epoch 2/10
# 8/8 [==============================] - 0s 50ms/step - loss: 29.6969 - accuracy: 0.6060 - val_loss: 16.1856 - val_accuracy: 0.6500
# Epoch 3/10
# 8/8 [==============================] - 0s 55ms/step - loss: 12.0535 - accuracy: 0.7800 - val_loss: 11.7852 - val_accuracy: 0.7400
# Epoch 4/10
# 8/8 [==============================] - 0s 54ms/step - loss: 10.8434 - accuracy: 0.7700 - val_loss: 12.4428 - val_accuracy: 0.7200
# Epoch 5/10
# 8/8 [==============================] - 0s 54ms/step - loss: 8.8472 - accuracy: 0.8020 - val_loss: 4.0330 - val_accuracy: 0.8500
# Epoch 6/10
# 8/8 [==============================] - 0s 53ms/step - loss: 5.8490 - accuracy: 0.8480 - val_loss: 5.4492 - val_accuracy: 0.8700
# Epoch 7/10
# 8/8 [==============================] - 0s 51ms/step - loss: 4.4320 - accuracy: 0.8580 - val_loss: 3.4839 - val_accuracy: 0.8700
# Epoch 8/10
# 8/8 [==============================] - 0s 50ms/step - loss: 4.4381 - accuracy: 0.8640 - val_loss: 3.5786 - val_accuracy: 0.9000
# Epoch 9/10
# 8/8 [==============================] - 0s 55ms/step - loss: 3.2788 - accuracy: 0.8760 - val_loss: 2.9145 - val_accuracy: 0.8900
# Epoch 10/10
# 8/8 [==============================] - 0s 56ms/step - loss: 2.9729 - accuracy: 0.8800 - val_loss: 2.8069 - val_accuracy: 0.9100

# %%
display_activation(model, 8, 4, 1)
print("MaxPooling en altérant le ratio de l'image")
# Out:
# WARNING:tensorflow:9 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000027F8C3D8040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# MaxPooling en altérant le ratio de l'image

# %% [markdown]
# ## Conclusion
#
# Il est impératif d'utiliser un Pooling "carré" pour conserver les proportions de l'image.
# Après plusieurs tests, le MaxPooling a donné de meilleurs résultats et sera donc conservé pour la suite.

# %% [markdown]
# ## Droupout
#
# Cette couche est difficile à observer. Son rôle est d'éteindre une partie des neuronnes (choisies au hasard) afin d'éviter le surapprentissage

# %%
## Dense

Comme le Dropout, cette couche n'est pas facilement observable. Elle "ajoute des couches à l'image",
# Out:
#   File "<ipython-input-1-ef34d94e7ba2>", line 3
#     Comme le Dropout, cette couche n'est pas facilement observable. Elle "ajoute des couches à l'image",
#           ^
# SyntaxError: invalid syntax
